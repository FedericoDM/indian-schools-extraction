# %% [markdown]
# # Webscrapeo de escuelas - INDIA

# %%
import time
import requests
import numpy as np
import pandas as pd

# %% [markdown]
# ## Funciones

# %%
def get_school_df(URL, newId, counter):
    """[Get School DataFrame by calling its API]

    Parameters
    ----------
    URL : [str]
        [String with the original URL]
    newId : [int]
        [Integer belonging to certain school]

    Returns
    -------
    [school_df]
        [DataFrame with the school's info]
    """
    
    new_API = URL.replace("objectIds=20", f"objectIds={newId}")
    r = requests.get(new_API)
    content = r.json()
    school_info = content['features'][0]['attributes']
    school_df = pd.DataFrame(school_info, index=[counter])
    school_df = school_df[['objectid_1', 'fid_school', 'objectid', 'schcd', 'schname', 'schcat',
       'school_cat', 'schtype', 'school_typ', 'schmgt', 'management', 'rururb', 'location', 
       'pincode', 'dtname', 'udise_stco', 'stname', 'longitude', 'latitude', 'stcode11', 'dtcode11']]
    
    school_df.rename(columns={"schcd": "school_code", "schname": "school_name"}, inplace=True)

    return school_df

# %% [markdown]
# ## Parámetros

# %%
URL = """https://geoportal.nic.in/nicgis/rest/services/SCHOOLGIS/Schooldata/MapServer/0/query?f=json&returnGeometry=true&spatialRel=esriSpatialRelIntersects&objectIds=20&outFields=*&outSR=102100&quantizationParameters=%7B%22mode%22%3A%22view%22%2C%22originPosition%22%3A%22upperLeft%22%2C%22tolerance%22%3A4.777314267948289%2C%22extent%22%3A%7B%22xmin%22%3A68.5015470000764%2C%22ymin%22%3A6.8114540002900235%2C%22xmax%22%3A97.02722199976724%2C%22ymax%22%3A35.032117999820365%2C%22spatialReference%22%3A%7B%22wkid%22%3A4326%2C%22latestWkid%22%3A4326%7D%7D%7D"""

# %%
short_URL = "https://geoportal.nic.in/nicgis/rest/services/SCHOOLGIS/Schooldata/MapServer/0/query?f=json&returnGeometry=true&spatialRel=esriSpatialRelIntersects&objectIds=20"

# %% [markdown]
# ## Pipeline

# %%
URL_2 = """https://geoportal.nic.in/nicgis/rest/services/SCHOOLGIS/Schooldata/MapServer/0/query?f=json&returnGeometry=true&spatialRel=esriSpatialRelIntersects&objectIds=0&outFields=*&outSR=102100&quantizationParameters=%7B%22mode%22%3A%22view%22%2C%22originPosition%22%3A%22upperLeft%22%2C%22tolerance%22%3A4.777314267948289%2C%22extent%22%3A%7B%22xmin%22%3A68.5015470000764%2C%22ymin%22%3A6.8114540002900235%2C%22xmax%22%3A97.02722199976724%2C%22ymax%22%3A35.032117999820365%2C%22spatialReference%22%3A%7B%22wkid%22%3A4326%2C%22latestWkid%22%3A4326%7D%7D%7D"""

# %%
r = requests.get(URL_2)
r.json()
# Out:
# {'displayFieldName': 'vilname',
#  'transform': {'originPosition': 'upperLeft',
#   'scale': [4.777314267948289, 4.777314267948289],
#   'translate': [68.5015470000764, 35.032117999820365]},
#  'fieldAliases': {'objectid_1': 'objectid_1',
#   'fid_school': 'fid_school',
#   'objectid': 'objectid',
#   'schcd': 'schcd',
#   'schname': 'School',
#   'schcat': 'Cat_Code',
#   'school_cat': 'Category',
#   'schtype': 'Type Code',
#   'school_typ': 'School Type',
#   'schmgt': 'Mngt Code',
#   'management': 'Management',
#   'rururb': 'Rural_Urban',
#   'location': 'Location',
#   'pincode': 'Pincode',
#   'dtname': 'District',
#   'udise_stco': 'udise_stco',
#   'stname': 'State',
#   'vilname': 'Village',
#   'longitude': 'longitude',
#   'latitude': 'latitude',
#   'stcode11': 'stcode11',
#   'dtcode11': 'dtcode11'},
#  'geometryType': 'esriGeometryPoint',
#  'spatialReference': {'wkid': 102100, 'latestWkid': 3857},
#  'fields': [{'name': 'objectid_1',
#    'type': 'esriFieldTypeOID',
#    'alias': 'objectid_1'},
#   {'name': 'fid_school',
#    'type': 'esriFieldTypeInteger',
#    'alias': 'fid_school'},
#   {'name': 'objectid', 'type': 'esriFieldTypeInteger', 'alias': 'objectid'},
#   {'name': 'schcd',
#    'type': 'esriFieldTypeString',
#    'alias': 'schcd',
#    'length': 11},
#   {'name': 'schname',
#    'type': 'esriFieldTypeString',
#    'alias': 'School',
#    'length': 150},
#   {'name': 'schcat', 'type': 'esriFieldTypeInteger', 'alias': 'Cat_Code'},
#   {'name': 'school_cat',
#    'type': 'esriFieldTypeString',
#    'alias': 'Category',
#    'length': 50},
#   {'name': 'schtype', 'type': 'esriFieldTypeInteger', 'alias': 'Type Code'},
#   {'name': 'school_typ',
#    'type': 'esriFieldTypeString',
#    'alias': 'School Type',
#    'length': 20},
#   {'name': 'schmgt', 'type': 'esriFieldTypeInteger', 'alias': 'Mngt Code'},
#   {'name': 'management',
#    'type': 'esriFieldTypeString',
#    'alias': 'Management',
#    'length': 50},
#   {'name': 'rururb',
#    'type': 'esriFieldTypeString',
#    'alias': 'Rural_Urban',
#    'length': 50},
#   {'name': 'location',
#    'type': 'esriFieldTypeString',
#    'alias': 'Location',
#    'length': 30},
#   {'name': 'pincode',
#    'type': 'esriFieldTypeString',
#    'alias': 'Pincode',
#    'length': 6},
#   {'name': 'dtname',
#    'type': 'esriFieldTypeString',
#    'alias': 'District',
#    'length': 50},
#   {'name': 'udise_stco',
#    'type': 'esriFieldTypeString',
#    'alias': 'udise_stco',
#    'length': 2},
#   {'name': 'stname',
#    'type': 'esriFieldTypeString',
#    'alias': 'State',
#    'length': 30},
#   {'name': 'vilname',
#    'type': 'esriFieldTypeString',
#    'alias': 'Village',
#    'length': 50},
#   {'name': 'longitude', 'type': 'esriFieldTypeDouble', 'alias': 'longitude'},
#   {'name': 'latitude', 'type': 'esriFieldTypeDouble', 'alias': 'latitude'},
#   {'name': 'stcode11',
#    'type': 'esriFieldTypeString',
#    'alias': 'stcode11',
#    'length': 2},
#   {'name': 'dtcode11',
#    'type': 'esriFieldTypeString',
#    'alias': 'dtcode11',
#    'length': 3}],
#  'features': []}

# %%
school_df = get_school_df(URL, 1488900, 1)
school_df
# Out:
#    objectid_1  fid_school  objectid school_code     school_name  schcat  \
# 1     1488900      531525    535786  1010302403  UPS AWATHKOOLI       2
#
#       school_cat  schtype school_typ  schmgt  ... rururb location pincode  \
# 1  Upper Primary        3      Co-Ed       1  ...      1           193224
#
#     dtname udise_stco           stname longitude  latitude  stcode11 dtcode11
# 1  Kupwara         01  JAMMU & KASHMIR   74.0756   34.5476        01      001
#
# [1 rows x 21 columns]

# %% [markdown]
# ## Probar con cierto número de escuelas

# %%
schools_df = pd.DataFrame([])
school_numbers = np.arange(1280001,1285001)
for school_number in school_numbers:
    try:
        school_df = get_school_df(URL, school_number, school_number)
        schools_df = pd.concat([schools_df, school_df], ignore_index=True)
        time.sleep(np.random.randint(0, 2))
    
    except Exception as err:
        print(str(err))
        print("Unable to get data")
        school_df = pd.DataFrame([])
        schools_df = pd.concat([schools_df, school_df], ignore_index=True)
        time.sleep(2)

    if school_number % 1000 == 0:
        time.sleep(4)
        print(f"{school_number} schools obtained")
        schools_df.to_csv(f"schools_df_{school_number}.csv", index=False, encoding='utf-8-sig')
# Out:
# 1281000 schools obtained
# 1282000 schools obtained
# 1283000 schools obtained
# 1284000 schools obtained
# 1285000 schools obtained

# %%
schools_df
# Out:
#        objectid_1  fid_school  objectid  school_code  \
# 0               1      233143    235240  35020300702
# 1               2      747816    753170  35020300201
# 2               3       55885     56582  35020300703
# 3               4      639587    644125  35020300701
# 4               5      223993    226006  35020300404
# ...           ...         ...       ...          ...
# 30043       30220     1320813   1335153  32070502903
# 30044       30221      198499    200320  33200704101
# 30045       30222     1057599   1064993  33150402609
# 30046       30223      579554    583943  33190303103
# 30047       30224      346481    349434  33130400905
#
#                                      school_name  schcat  \
# 0              GOVT PRIMARY SCHOOL SHASTRI NAGAR       1
# 1             GOVT SECONDARY SCHOOL GANDHI NAGAR       6
# 2                GOVT PRIMARY SCHOOL LAXMI NAGAR       1
# 3       GOVT SENIOR SECONDARY SCHOOL VIJAY NAGAR       3
# 4                    GOVT PRIMARY SCHOOL CHINGAN       1
# ...                                          ...     ...
# 30043                       ANSAR ENGLISH SCHOOL       3
# 30044                      PUPS, KUDITHANGICHERI       1
# 30045  ST.JOSEPH'S HR. SEC. SCHOOL, NAGAMANGALAM       3
# 30046                           PUMS KERALANTHAN       2
# 30047                            PUPS, SANIPATTI       1
#
#                     school_cat  schtype school_typ  schmgt  ... rururb  \
# 0                      Primary        3      Co-Ed       1  ...      1
# 1             Secondary (1-10)        3      Co-Ed       1  ...      1
# 2                      Primary        3      Co-Ed       1  ...      1
# 3      Higher Secondary (1-12)        3      Co-Ed       1  ...      1
# 4                      Primary        3      Co-Ed       1  ...      1
# ...                        ...      ...        ...     ...  ...    ...
# 30043  Higher Secondary (1-12)        3      Co-Ed       5  ...      1
# 30044                  Primary        3      Co-Ed       1  ...      1
# 30045  Higher Secondary (1-12)        3      Co-Ed       4  ...      1
# 30046            Upper Primary        3      Co-Ed       1  ...      1
# 30047                  Primary        3      Co-Ed       1  ...      1
#
#       location pincode           dtname udise_stco             stname  \
# 0               744302         Nicobars         35  ANDAMAN & NICOBAR
# 1               744302         Nicobars         35  ANDAMAN & NICOBAR
# 2               744302         Nicobars         35  ANDAMAN & NICOBAR
# 3               744302         Nicobars         35  ANDAMAN & NICOBAR
# 4               744302         Nicobars         35  ANDAMAN & NICOBAR
# ...        ...     ...              ...        ...                ...
# 30043           680519         Thrissur         32             KERALA
# 30044           614102       Thiruvarur         33         TAMIL NADU
# 30045           620012  Tiruchirappalli         33         TAMIL NADU
# 30046           610106       Thiruvarur         33         TAMIL NADU
# 30047           624620            Karur         33         TAMIL NADU
#
#        longitude   latitude  stcode11 dtcode11
# 0      93.892304   6.811454        35      638
# 1      93.890508   6.838517        35      638
# 2      93.886408   6.893214        35      638
# 3      93.919901   6.961255        35      638
# 4      93.912472   6.972397        35      638
# ...          ...        ...       ...      ...
# 30043  76.089887  10.699364        32      594
# 30044  79.499640  10.699370        33      619
# 30045  78.621328  10.699393        33      614
# 30046  79.652170  10.699410        33      619
# 30047  78.149321  10.699423        33      613
#
# [30048 rows x 21 columns]
